# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import truncnorm
import math
import pandas as pd
import scipy.stats as sc
import random

# %%
# Q5

def s_to_t(s1, s2, std_t): #Function to get t|s1,s2,y with s1, s2 as given values
    return truncnorm.rvs(0 - (s1-s2)/std_t, (np.inf - (s1-s2)/std_t), loc = (s1-s2), scale = std_t)

def t_to_s(t, mu_s_vector, std_s_matrix, A): #Function to get s1,s2|t,y with t as a given value
    std_s_matrix_old = std_s_matrix
    std_s_matrix = np.linalg.inv(np.linalg.inv(std_s_matrix_old) + (A.reshape(-1, 1) * (1/std_t)) @ A)
    mu_s_vector = std_s_matrix@(np.linalg.inv(std_s_matrix_old) @ mu_s_vector + A.reshape(-1, 1) * (1/std_t)*t)
    mu_s_transpose = mu_s_vector.reshape(1, -1)[0]
    return np.random.multivariate_normal(mu_s_transpose, std_s_matrix)

def normal_dist(mu, sig, t):
    return (1/np.sqrt(2*np.pi*sig))*np.exp(-((t-mu)**2)/(2*sig))


#Timer
time_taken = time.time()

#Starting µ and σ for S
mu_s = 1
std_s = 4
x_distri = np.linspace(-20,20,10000)
s1_dist = normal_dist(mu_s, std_s, x_distri)
s2_dist = normal_dist(mu_s, std_s, x_distri)
#The start is a ROW since it is an input to a function that generates 2d normal distributions
# The vector is a COLUMN since it is used in calculations as was done in Q3
mu_s_start = np.array([mu_s, mu_s])
mu_s_vector = np.array([[mu_s], [mu_s]])
std_s_matrix = np.array([[std_s**2, 0], [0, std_s**2]])
std_s_start = np.array([[std_s**2, 0], [0, std_s**2]])
A = np.array([[1, -1]]) # A-vector in the calculations
std_t = 5 # σ for t

Iters = 2000 #iterations
ab = 3 # burnout period
All_S = np.zeros((Iters, 2)) #Containing drawn S values
All_t = np.zeros(Iters) #Containing drawn t values

# Matrices where the s1 and s2 random values are stored as well as the µ-values (in All_Mu_S)
All_S[0] = [np.random.normal(loc=mu_s, scale = std_s), np.random.normal(loc=mu_s, scale = std_s)]

# We calculate t, then s, and repeat for as many times as the iterations
for i in range(Iters-1):
    All_t[i] = s_to_t(All_S[i,0], All_S[i,1], std_t)
    All_S[i+1] = t_to_s(All_t[i], mu_s_vector, std_s_matrix, A)

# Result vectors, x stores iterations, y stores s1 and s2, w stores µ1 and µ2
x = [i for i in range(ab,Iters)]
y1 = [All_S[i][0] for i in range(ab,Iters)]
y2 = [All_S[i][1] for i in range(ab,Iters)]


# How s changes (after burnout period)
plt.plot(x,y1)
plt.plot(x,y2)
plt.legend(["s_1", "s_2"])
plt.xlabel("Iterations")
plt.ylabel("s-value")
plt.show()

#FINDING NEW MEAN AND CO VARIANCE FROM DRAWN S1 AND S2 FOR POSTERIOR DISTRIBUTION

#Finding mean
mu_S1 = np.mean(y1)
mu_S2 = np.mean(y2)

#Finding the Covariance matrix
co_11 = 0
co_121 = 0
co_22 = 0

for i in range(len(y1)):
    co_11 += (y1[i]-mu_S1)**2
    co_22 += (y2[i]-mu_S2)**2
    co_121 += (y1[i]-mu_S1)*(y2[i]-mu_S2)

co_11 /= len(y1)-1
co_121 /= len(y1)-1
co_22 /= len(y2)-1

# Putting the results into a vector (µ) and a matrix (covariance)
mu_vector = np.array([mu_S1, mu_S2])
covariance_matrix = np.array([[co_11, co_121], [co_121, co_22]])


s1_ny_dist = normal_dist(mu_S1, co_11, x_distri)
s2_ny_dist = normal_dist(mu_S2, co_22, x_distri)

# Samples excluding the burnout period
samples_drawn = Iters - ab

# Draws samples from the original µ values and covariance matrix, the draws values from the new M values and covariance matrix
All_samples_drawn = np.zeros((samples_drawn, 2))
Samples_from_start = np.zeros((samples_drawn, 2))
for i in range(samples_drawn):
    All_samples_drawn[i] = np.random.multivariate_normal(mu_vector, covariance_matrix)
    Samples_from_start[i] = np.random.multivariate_normal(mu_s_start, std_s_start)

#Results are split into new s1, s2 and starting value for s1, s2
newy1 = [All_samples_drawn[i][0] for i in range(samples_drawn)]
newy2 = [All_samples_drawn[i][1] for i in range(samples_drawn)]

#start1 = [Samples_from_start[i][0] for i in range(samples_drawn)]
#start2 = [Samples_from_start[i][1] for i in range(samples_drawn)]

#Timer stops, for accurate time comment out all the plots
time_taken = time.time() - time_taken
print(f"Time taken = {time_taken}")

#Shows the new distribution
figure, axis = plt.subplots(1,2)
axis[0].hist(newy1, density=1, bins=20)
axis[0].plot(x_distri, s1_ny_dist)
axis[0].legend(["s_1 (Histogram)", "s_1 (Distribution)"])

axis[1].hist(newy2, density=1, bins=20)
axis[1].plot(x_distri, s2_ny_dist)
axis[1].legend(["s_2 (Histogram)", "s_2 (Distribution)"])

plt.xlabel("s-value")
plt.ylabel("Occurences")
plt.title(f"{Iters} iterations, took {round(time_taken, 2)} seconds")

plt.show()

#shows the start distribution (s1, s2) and the resulting distribution (s1, s2|y)
figure, axis = plt.subplots(1,2)
axis[0].plot(x_distri, s1_dist)
axis[0].plot(x_distri, s1_ny_dist)
axis[0].legend(['s_1', 's_1|y'])

axis[1].plot(x_distri, s2_dist)
axis[1].plot(x_distri, s2_ny_dist)
axis[1].legend(['s_2', 's_2|y'])

plt.xlabel("Value")
plt.ylabel("Probability")
plt.show()
# Out:
# Time taken = 1.1542043685913086

# %%
# Q7
def prediction(mu1, mu2):
    #Predicts outcome of match
    if mu1 >= mu2:
        return 1
    return -1

# %%
# Q6
#Class for every team, showing µ, σ and team name
class team:
    def __init__(self, mu, var, name, skill):
        self.mu = mu
        self.var = var
        self.name = name
        self.skill = skill

def s_to_t(s1, s2, std_t, score): #Function to get t|s1,s2,y with s1, s2 as given values
    if score == -1:
        minval, maxval = -np.inf, 0
    else:
        minval, maxval = 0, np.inf
    return truncnorm.rvs(minval - (s1-s2)/std_t, (maxval - (s1-s2)/std_t), loc = (s1-s2), scale = std_t)

def t_to_s(t, A, std_t, std_s_matrix, mu_s_vector): #Function to get s1,s2|t,y with t as a given value
    std_s_matrix_old = std_s_matrix
    std_s_matrix = np.linalg.inv(np.linalg.inv(std_s_matrix_old) + (A.reshape(-1, 1) * (1/std_t)) @ A)
    mu_s_vector = std_s_matrix@(np.linalg.inv(std_s_matrix_old) @ mu_s_vector + A.reshape(-1, 1) * (1/std_t)*t)
    mu_s_transpose = mu_s_vector.reshape(1, -1)[0]
    return np.random.multivariate_normal(mu_s_transpose, std_s_matrix)

std_t = 5 # starting σ for t

#Reads the data, the path has to be changed depending on where your target folder is in vs code, here the target folder is AML
input_data = pd.read_csv("SerieA.csv")

#Creates list of names
team_list = []
for teams in input_data["team1"]:
    if teams not in team_list:
        team_list.append(teams)

for teams in input_data["team2"]:
    if teams not in team_list:
        team_list.append(teams)

#Creates a list with all the teams (i.e. a list of classes)
team_data = []
for i in team_list:
    team_data.append(team(1,4,i,0))

Iters = 1000 #Iterations
ab = 20 #After burnout
A = np.array([[1, -1]]) # A-vector in the calculations

#Main loop
nr_matches = len(input_data["team1"])
correct_predictions = 0
used_matches = 0 #We only use matches that are not tied
for iteration in range(nr_matches):
    print(f"Calculating match {iteration} of {nr_matches}")
    i = iteration # Doing matches in sequence
    #i = nr_matches-1-iteration # doing matches in reverse
    #Get the score, if score is 0, the match is ignored
    score = input_data["score1"][i] - input_data["score2"][i]
    if score == 0:
        continue
    used_matches += 1

    #Only the sign of the score is used
    score = np.sign(score)

    #Get the correct team data by fetching the names and then using the classes corresponding to those names
    team_1_name = input_data["team1"][i]
    team_2_name = input_data["team2"][i]

    for j in range(len(team_data)):
        if team_data[j].name == team_1_name:
            team1 = team_data[j]
        if team_data[j].name == team_2_name:
            team2 = team_data[j]
    
    #Predicting outcome
    mu1 = team1.mu
    mu2 = team2.mu
    pred_outcome = prediction(mu1, mu2)
    if pred_outcome == score:
        correct_predictions += 1
            
    #Set up µ-vector and covariance matrix
    mu_s_vector = np.array([[team1.mu], [team2.mu]])
    std_s_matrix = np.array([[team1.var**2, 0], [0, team2.var**2]])

    All_S = np.zeros((Iters, 2)) #Containing drawn S values
    All_t = np.zeros(Iters) #Containing drawn t values

    # Matrices where the s1 and s2 random values are stored as well as the µ-values (in All_Mu_S)
    All_S[0] = [np.random.normal(loc=team1.mu, scale = team1.var), np.random.normal(loc=team2.mu, scale = team2.var)]

    # We calculate t, then s, and repeat for as many times as the iterations
    for j in range(Iters-1):
        All_t[j] = s_to_t(All_S[j,0], All_S[j,1], std_t, score)
        All_S[j+1] = t_to_s(All_t[j], A, std_t, std_s_matrix, mu_s_vector)

    #Getting s1 and s2 values
    y1 = [All_S[j][0] for j in range(ab,Iters)]
    y2 = [All_S[j][1] for j in range(ab,Iters)]

    #Getting µ and σ
    mu_team1 = np.mean(y1)
    mu_team2 = np.mean(y2)
    var_team1 = 0
    var_team2 = 0
    for j in range(len(y1)):
        var_team1 += (y1[j]-mu_team1)**2
        var_team2 += (y2[j]-mu_team2)**2
    var_team1 /= len(y1)-1
    var_team2 /= len(y1)-1
    var_team1 = math.sqrt(var_team1)
    var_team2 = math.sqrt(var_team2)
    team1.mu = mu_team1
    team2.mu = mu_team2
    team1.var = var_team1
    team2.var = var_team2


#Calculating prediction rate
prediction_rate = correct_predictions/used_matches
    
#Drawing 100 random numbers from the distributions to determine skill
for current_team in team_data:
    for i in range(100):
        partial_skill = np.random.normal(loc=current_team.mu, scale = current_team.var)/100
        current_team.skill += partial_skill

team_data.sort(key=lambda team: team.skill, reverse=True)

print("TEAM SKILLS AND RANKINGS:")
for i in range(len(team_data)):
    print(f"{i+1}. {team_data[i].name}: Skill = {round(team_data[i].skill, 2)}, µ = {round(team_data[i].mu, 2)}, sig = {round(team_data[i].var, 2)}")
print(f"prediction rate = {prediction_rate}")
# Out:
# Calculating match 0 of 380
# Calculating match 1 of 380
# Calculating match 2 of 380
# Calculating match 3 of 380
# Calculating match 4 of 380
# Calculating match 5 of 380
# Calculating match 6 of 380
# Calculating match 7 of 380
# Calculating match 8 of 380
# Calculating match 9 of 380
# Calculating match 10 of 380
# Calculating match 11 of 380
# Calculating match 12 of 380
# Calculating match 13 of 380
# Calculating match 14 of 380
# Calculating match 15 of 380
# Calculating match 16 of 380
# Calculating match 17 of 380
# Calculating match 18 of 380
# Calculating match 19 of 380
# Calculating match 20 of 380
# Calculating match 21 of 380
# Calculating match 22 of 380
# Calculating match 23 of 380
# Calculating match 24 of 380
# Calculating match 25 of 380
# Calculating match 26 of 380
# Calculating match 27 of 380
# Calculating match 28 of 380
# Calculating match 29 of 380
# Calculating match 30 of 380
# Calculating match 31 of 380
# Calculating match 32 of 380
# Calculating match 33 of 380
# Calculating match 34 of 380
# Calculating match 35 of 380
# Calculating match 36 of 380
# Calculating match 37 of 380
# Calculating match 38 of 380
# Calculating match 39 of 380
# Calculating match 40 of 380
# Calculating match 41 of 380
# Calculating match 42 of 380
# Calculating match 43 of 380
# Calculating match 44 of 380
# Calculating match 45 of 380
# Calculating match 46 of 380
# Calculating match 47 of 380
# Calculating match 48 of 380
# Calculating match 49 of 380
# Calculating match 50 of 380
# Calculating match 51 of 380
# Calculating match 52 of 380
# Calculating match 53 of 380
# Calculating match 54 of 380
# Calculating match 55 of 380
# Calculating match 56 of 380
# Calculating match 57 of 380
# Calculating match 58 of 380
# Calculating match 59 of 380
# Calculating match 60 of 380
# Calculating match 61 of 380
# Calculating match 62 of 380
# Calculating match 63 of 380
# Calculating match 64 of 380
# Calculating match 65 of 380
# Calculating match 66 of 380
# Calculating match 67 of 380
# Calculating match 68 of 380
# Calculating match 69 of 380
# Calculating match 70 of 380
# Calculating match 71 of 380
# Calculating match 72 of 380
# Calculating match 73 of 380
# Calculating match 74 of 380
# Calculating match 75 of 380
# Calculating match 76 of 380
# Calculating match 77 of 380
# Calculating match 78 of 380
# Calculating match 79 of 380
# Calculating match 80 of 380
# Calculating match 81 of 380
# Calculating match 82 of 380
# Calculating match 83 of 380
# Calculating match 84 of 380
# Calculating match 85 of 380
# Calculating match 86 of 380
# Calculating match 87 of 380
# Calculating match 88 of 380
# Calculating match 89 of 380
# Calculating match 90 of 380
# Calculating match 91 of 380
# Calculating match 92 of 380
# Calculating match 93 of 380
# Calculating match 94 of 380
# Calculating match 95 of 380
# Calculating match 96 of 380
# Calculating match 97 of 380
# Calculating match 98 of 380
# Calculating match 99 of 380
# Calculating match 100 of 380
# Calculating match 101 of 380
# Calculating match 102 of 380
# Calculating match 103 of 380
# Calculating match 104 of 380
# Calculating match 105 of 380
# Calculating match 106 of 380
# Calculating match 107 of 380
# Calculating match 108 of 380
# Calculating match 109 of 380
# Calculating match 110 of 380
# Calculating match 111 of 380
# Calculating match 112 of 380
# Calculating match 113 of 380
# Calculating match 114 of 380
# Calculating match 115 of 380
# Calculating match 116 of 380
# Calculating match 117 of 380
# Calculating match 118 of 380
# Calculating match 119 of 380
# Calculating match 120 of 380
# Calculating match 121 of 380
# Calculating match 122 of 380
# Calculating match 123 of 380
# Calculating match 124 of 380
# Calculating match 125 of 380
# Calculating match 126 of 380
# Calculating match 127 of 380
# Calculating match 128 of 380
# Calculating match 129 of 380
# Calculating match 130 of 380
# Calculating match 131 of 380
# Calculating match 132 of 380
# Calculating match 133 of 380
# Calculating match 134 of 380
# Calculating match 135 of 380
# Calculating match 136 of 380
# Calculating match 137 of 380
# Calculating match 138 of 380
# Calculating match 139 of 380
# Calculating match 140 of 380
# Calculating match 141 of 380
# Calculating match 142 of 380
# Calculating match 143 of 380
# Calculating match 144 of 380
# Calculating match 145 of 380
# Calculating match 146 of 380
# Calculating match 147 of 380
# Calculating match 148 of 380
# Calculating match 149 of 380
# Calculating match 150 of 380
# Calculating match 151 of 380
# Calculating match 152 of 380
# Calculating match 153 of 380
# Calculating match 154 of 380
# Calculating match 155 of 380
# Calculating match 156 of 380
# Calculating match 157 of 380
# Calculating match 158 of 380
# Calculating match 159 of 380
# Calculating match 160 of 380
# Calculating match 161 of 380
# Calculating match 162 of 380
# Calculating match 163 of 380
# Calculating match 164 of 380
# Calculating match 165 of 380
# Calculating match 166 of 380
# Calculating match 167 of 380
# Calculating match 168 of 380
# Calculating match 169 of 380
# Calculating match 170 of 380
# Calculating match 171 of 380
# Calculating match 172 of 380
# Calculating match 173 of 380
# Calculating match 174 of 380
# Calculating match 175 of 380
# Calculating match 176 of 380
# Calculating match 177 of 380
# Calculating match 178 of 380
# Calculating match 179 of 380
# Calculating match 180 of 380
# Calculating match 181 of 380
# Calculating match 182 of 380
# Calculating match 183 of 380
# Calculating match 184 of 380
# Calculating match 185 of 380
# Calculating match 186 of 380
# Calculating match 187 of 380
# Calculating match 188 of 380
# Calculating match 189 of 380
# Calculating match 190 of 380
# Calculating match 191 of 380
# Calculating match 192 of 380
# Calculating match 193 of 380
# Calculating match 194 of 380
# Calculating match 195 of 380
# Calculating match 196 of 380
# Calculating match 197 of 380
# Calculating match 198 of 380
# Calculating match 199 of 380
# Calculating match 200 of 380
# Calculating match 201 of 380
# Calculating match 202 of 380
# Calculating match 203 of 380
# Calculating match 204 of 380
# Calculating match 205 of 380
# Calculating match 206 of 380
# Calculating match 207 of 380
# Calculating match 208 of 380
# Calculating match 209 of 380
# Calculating match 210 of 380
# Calculating match 211 of 380
# Calculating match 212 of 380
# Calculating match 213 of 380
# Calculating match 214 of 380
# Calculating match 215 of 380
# Calculating match 216 of 380
# Calculating match 217 of 380
# Calculating match 218 of 380
# Calculating match 219 of 380
# Calculating match 220 of 380
# Calculating match 221 of 380
# Calculating match 222 of 380
# Calculating match 223 of 380
# Calculating match 224 of 380
# Calculating match 225 of 380
# Calculating match 226 of 380
# Calculating match 227 of 380
# Calculating match 228 of 380
# Calculating match 229 of 380
# Calculating match 230 of 380
# Calculating match 231 of 380
# Calculating match 232 of 380
# Calculating match 233 of 380
# Calculating match 234 of 380
# Calculating match 235 of 380
# Calculating match 236 of 380
# Calculating match 237 of 380
# Calculating match 238 of 380
# Calculating match 239 of 380
# Calculating match 240 of 380
# Calculating match 241 of 380
# Calculating match 242 of 380
# Calculating match 243 of 380
# Calculating match 244 of 380
# Calculating match 245 of 380
# Calculating match 246 of 380
# Calculating match 247 of 380
# Calculating match 248 of 380
# Calculating match 249 of 380
# Calculating match 250 of 380
# Calculating match 251 of 380
# Calculating match 252 of 380
# Calculating match 253 of 380
# Calculating match 254 of 380
# Calculating match 255 of 380
# Calculating match 256 of 380
# Calculating match 257 of 380
# Calculating match 258 of 380
# Calculating match 259 of 380
# Calculating match 260 of 380
# Calculating match 261 of 380
# Calculating match 262 of 380
# Calculating match 263 of 380
# Calculating match 264 of 380
# Calculating match 265 of 380
# Calculating match 266 of 380
# Calculating match 267 of 380
# Calculating match 268 of 380
# Calculating match 269 of 380
# Calculating match 270 of 380
# Calculating match 271 of 380
# Calculating match 272 of 380
# Calculating match 273 of 380
# Calculating match 274 of 380
# Calculating match 275 of 380
# Calculating match 276 of 380
# Calculating match 277 of 380
# Calculating match 278 of 380
# Calculating match 279 of 380
# Calculating match 280 of 380
# Calculating match 281 of 380
# Calculating match 282 of 380
# Calculating match 283 of 380
# Calculating match 284 of 380
# Calculating match 285 of 380
# Calculating match 286 of 380
# Calculating match 287 of 380
# Calculating match 288 of 380
# Calculating match 289 of 380
# Calculating match 290 of 380
# Calculating match 291 of 380
# Calculating match 292 of 380
# Calculating match 293 of 380
# Calculating match 294 of 380
# Calculating match 295 of 380
# Calculating match 296 of 380
# Calculating match 297 of 380
# Calculating match 298 of 380
# Calculating match 299 of 380
# Calculating match 300 of 380
# Calculating match 301 of 380
# Calculating match 302 of 380
# Calculating match 303 of 380
# Calculating match 304 of 380
# Calculating match 305 of 380
# Calculating match 306 of 380
# Calculating match 307 of 380
# Calculating match 308 of 380
# Calculating match 309 of 380
# Calculating match 310 of 380
# Calculating match 311 of 380
# Calculating match 312 of 380
# Calculating match 313 of 380
# Calculating match 314 of 380
# Calculating match 315 of 380
# Calculating match 316 of 380
# Calculating match 317 of 380
# Calculating match 318 of 380
# Calculating match 319 of 380
# Calculating match 320 of 380
# Calculating match 321 of 380
# Calculating match 322 of 380
# Calculating match 323 of 380
# Calculating match 324 of 380
# Calculating match 325 of 380
# Calculating match 326 of 380
# Calculating match 327 of 380
# Calculating match 328 of 380
# Calculating match 329 of 380
# Calculating match 330 of 380
# Calculating match 331 of 380
# Calculating match 332 of 380
# Calculating match 333 of 380
# Calculating match 334 of 380
# Calculating match 335 of 380
# Calculating match 336 of 380
# Calculating match 337 of 380
# Calculating match 338 of 380
# Calculating match 339 of 380
# Calculating match 340 of 380
# Calculating match 341 of 380
# Calculating match 342 of 380
# Calculating match 343 of 380
# Calculating match 344 of 380
# Calculating match 345 of 380
# Calculating match 346 of 380
# Calculating match 347 of 380
# Calculating match 348 of 380
# Calculating match 349 of 380
# Calculating match 350 of 380
# Calculating match 351 of 380
# Calculating match 352 of 380
# Calculating match 353 of 380
# Calculating match 354 of 380
# Calculating match 355 of 380
# Calculating match 356 of 380
# Calculating match 357 of 380
# Calculating match 358 of 380
# Calculating match 359 of 380
# Calculating match 360 of 380
# Calculating match 361 of 380
# Calculating match 362 of 380
# Calculating match 363 of 380
# Calculating match 364 of 380
# Calculating match 365 of 380
# Calculating match 366 of 380
# Calculating match 367 of 380
# Calculating match 368 of 380
# Calculating match 369 of 380
# Calculating match 370 of 380
# Calculating match 371 of 380
# Calculating match 372 of 380
# Calculating match 373 of 380
# Calculating match 374 of 380
# Calculating match 375 of 380
# Calculating match 376 of 380
# Calculating match 377 of 380
# Calculating match 378 of 380
# Calculating match 379 of 380
# TEAM SKILLS AND RANKINGS:
# 1. Atalanta: Skill = 43.2, µ = 39.87, sig = 24.94
# 2. Udinese: Skill = 28.55, µ = 28.02, sig = 14.93
# 3. Milan: Skill = 27.97, µ = 27.61, sig = 13.02
# 4. Bologna: Skill = 20.02, µ = 19.6, sig = 8.78
# 5. Torino: Skill = 17.1, µ = 17.11, sig = 6.11
# 6. Roma: Skill = 12.58, µ = 12.31, sig = 5.1
# 7. Inter: Skill = 7.15, µ = 7.24, sig = 4.44
# 8. Spal: Skill = 1.76, µ = 2.47, sig = 4.52
# 9. Lazio: Skill = 1.23, µ = 0.92, sig = 7.56
# 10. Napoli: Skill = 0.35, µ = 0.73, sig = 14.64
# 11. Sassuolo: Skill = -2.94, µ = -2.84, sig = 8.86
# 12. Cagliari: Skill = -6.59, µ = -6.45, sig = 5.45
# 13. Parma: Skill = -7.25, µ = -5.59, sig = 7.74
# 14. Empoli: Skill = -7.41, µ = -6.73, sig = 13.03
# 15. Sampdoria: Skill = -9.06, µ = -8.6, sig = 10.51
# 16. Fiorentina: Skill = -11.8, µ = -12.19, sig = 3.71
# 17. Genoa: Skill = -18.26, µ = -20.39, sig = 11.09
# 18. Chievo: Skill = -18.48, µ = -18.43, sig = 15.21
# 19. Juventus: Skill = -29.91, µ = -32.17, sig = 13.25
# 20. Frosinone: Skill = -53.29, µ = -54.04, sig = 21.36
# prediction rate = 0.6102941176470589

# %%
# Q9
def s_to_t(s1, s2, std_t): #Function to get t|s1,s2,y with s1, s2 as given values
    return truncnorm.rvs(0 - (s1-s2)/std_t, (np.inf - (s1-s2)/std_t), loc = (s1-s2), scale = std_t)

def t_to_s(t, mu_s_vector, std_s_matrix, A, std_t): #Function to get s1,s2|t,y with t as a given value
    std_s_matrix_old = std_s_matrix
    std_s_matrix = np.linalg.inv(np.linalg.inv(std_s_matrix_old) + (A.reshape(-1, 1) * (1/std_t)) @ A)
    mu_s_vector = std_s_matrix@(np.linalg.inv(std_s_matrix_old) @ mu_s_vector + A.reshape(-1, 1) * (1/std_t)*t)
    mu_s_transpose = mu_s_vector.reshape(1, -1)[0]
    return np.random.multivariate_normal(mu_s_transpose, std_s_matrix)

def main():
    # initial
    mean_1 = 0
    var_1 = 4
    mean_2 = 0
    var_2 = 4
    beta = 5
    y = 1

    mu_s_vector = np.array([[mean_1], [mean_2]])
    std_s_matrix = np.array([[var_1, 0], [0, var_2]])
    A = np.array([[1, -1]]) # A-vector in the calculations

    Iters = 2000 #iterations
    ab = 30 # burnout period

    All_S = np.zeros((Iters, 2)) #Containing drawn S values
    All_t = np.zeros(Iters) #Containing drawn t values

    # Matrices where the s1 and s2 random values are stored as well as the µ-values (in All_Mu_S)
    All_S[0] = [np.random.normal(loc=mean_1, scale = np.sqrt(var_1)), np.random.normal(loc=mean_2, scale = np.sqrt(var_2))]

    # We calculate t, then s, and repeat for as many times as the iterations
    for i in range(Iters-1):
        All_t[i] = s_to_t(All_S[i,0], All_S[i,1], np.sqrt(beta))
        All_S[i+1] = t_to_s(All_t[i], mu_s_vector, std_s_matrix, A, np.sqrt(beta))

    # Result vectors, x stores iterations, y stores s1 and s2, w stores µ1 and µ2
    x = [i for i in range(ab,Iters)]
    y1 = [All_S[i][0] for i in range(ab,Iters)]
    y2 = [All_S[i][1] for i in range(ab,Iters)]
    #Finding mean
    mu_S1 = np.mean(y1)
    mu_S2 = np.mean(y2)

    #Finding the Covariance matrix
    co_11 = 0
    co_121 = 0
    co_22 = 0

    for i in range(len(y1)):
        co_11 += (y1[i]-mu_S1)**2
        co_22 += (y2[i]-mu_S2)**2
        co_121 += (y1[i]-mu_S1)*(y2[i]-mu_S2)

    co_11 /= len(y1)-1
    co_121 /= len(y1)-1
    co_22 /= len(y2)-1
    samples_drawn = Iters - ab

    # Putting the results into a vector (µ) and a matrix (covariance)
    mu_vector = np.array([mu_S1, mu_S2])
    covariance_matrix = np.array([[co_11, co_121], [co_121, co_22]])
    # Draws samples from the original µ values and covariance matrix, the draws values from the new M values and covariance matrix
    All_samples_drawn = np.zeros((samples_drawn, 2))
    for i in range(samples_drawn):
        All_samples_drawn[i] = np.random.multivariate_normal(mu_vector, covariance_matrix)

    #Results are split into new s1, s2 and starting value for s1, s2
    newy1 = [All_samples_drawn[i][0] for i in range(samples_drawn)]
    newy2 = [All_samples_drawn[i][1] for i in range(samples_drawn)]

    # fc to t
    mean_fct = mean_1 - mean_2 #(np.array([1, -1])@np.array([[mean_1], [mean_2]]))[0]
    var_fct = beta + var_1 + var_2 #beta + np.array([1, -1])@np.array([[var_1, 0], [0, var_2]])@np.array([1, -1]).T

    # fd to t
    if y == 1:
        a, b = 0, 1000
    else:
        a, b = -1000, 0

    # q(t) approximation of p(t|y)
    a = (a - mean_fct)/np.sqrt(var_fct)
    b = (b - mean_fct)/np.sqrt(var_fct)
    mean_q = truncnorm.mean(a, b, loc=mean_fct, scale=np.sqrt(var_fct))
    var_q = truncnorm.var(a, b, loc=mean_fct, scale=np.sqrt(var_fct))

    # message passing algorithm

    # t to fc
    mean_tfc = (mean_q*var_fct - mean_fct*var_q)/(var_fct - var_q)
    var_tfc = (var_q*var_fct)/(var_fct - var_q)

    # fc to s1
    mean_fcs1 = mean_tfc + mean_2 #(np.array([1, 1])@np.array([[mean_tfc], [mean_2]]))[0]
    var_fcs1 = beta + var_tfc + var_2 #beta + np.array([1, 1])@np.array([[var_tfc, 0],[0, var_2]])@np.array([1, 1]).T

    # p(s1|y)
    mean_s1Iy = (mean_fcs1*var_1 + mean_1*var_fcs1)/(var_fcs1 + var_1)
    var_s1Iy = (var_fcs1*var_1)/(var_1 + var_fcs1) 

    # fc to s2
    mean_fcs2 = (np.array([1, -1])@np.array([[mean_1], [mean_tfc]]))[0]
    var_fcs2 = beta + np.array([1, -1])@np.array([[var_tfc, 0], [0, var_1]])@np.array([1, -1]).T

    # p(s2|y)
    mean_s2Iy = (mean_fcs2*var_2 + mean_2*var_fcs2)/(var_fcs2 + var_2)
    var_s2Iy = var_fcs2*var_2/(var_2 + var_fcs2)




    # plot

    # posteriors
    x = np.linspace(-7, 7, num=1000)
    plt.plot(x, sc.norm.pdf(x, mu_S1, np.sqrt(co_11)))
    plt.plot(x, sc.norm.pdf(x, mu_S2, np.sqrt(co_22)))
    plt.hist(newy1, density=1, bins=20)
    plt.hist(newy2, density=1, bins=20)
    plt.plot(x, sc.norm.pdf(x, mean_s1Iy, np.sqrt(var_s1Iy)))
    plt.plot(x, sc.norm.pdf(x, mean_s2Iy, np.sqrt(var_s2Iy)))
    plt.legend(["S1 (Gibbs)", "S2 (Gibbs)", "S1 (Message)", "S2 (Message)","S1 Gibbs Histogram", "S2 Gibbs Histogram"])
    plt.xlabel("Value")
    plt.ylabel("Probability")
    plt.title("Comparison of skill distributions")
    plt.show()
    


if __name__ == '__main__':
    main()

# %%
# Q10
#Class for every team, showing µ, σ and team name
class team:
    def __init__(self, mu, var, name, skill):
        self.mu = mu
        self.var = var
        self.name = name
        self.skill = skill

def s_to_t(s1, s2, std_t, score): #Function to get t|s1,s2,y with s1, s2 as given values
    score=np.sign(score)
    if score == -1:
        minval, maxval = -np.inf, 0
    else:
        minval, maxval = 0, np.inf
    return truncnorm.rvs(minval - (s1-s2)/std_t, (maxval - (s1-s2)/std_t), loc = (s1-s2), scale = std_t)

def t_to_s(t, A, std_t,std_s_matrix, mu_s_vector): #Function to get s1,s2|t,y with t as a given value
    std_s_matrix_old = std_s_matrix
    std_s_matrix = np.linalg.inv(np.linalg.inv(std_s_matrix_old) + (A.reshape(-1, 1) * (1/std_t)) @ A)
    mu_s_vector = std_s_matrix@(np.linalg.inv(std_s_matrix_old) @ mu_s_vector + A.reshape(-1, 1) * (1/std_t)*t)
    mu_s_transpose = mu_s_vector.reshape(1, -1)[0]
    return np.random.multivariate_normal(mu_s_transpose, std_s_matrix)

std_t = 5 # starting σ for t

#Reads the data, the path has to be changed depending on where your target folder is in vs code, here the target folder is AML
input_data = pd.read_csv("res_fence_short.csv")

input_data

#Creates list of names
team_list = []
for teams in input_data["ID1"]:
    if teams not in team_list:
        team_list.append(teams)

for teams in input_data["ID2"]:
    if teams not in team_list:
        team_list.append(teams)

#Creates a list with all the teams (i.e. a list of classes)
team_data = []
for i in team_list:
    team_data.append(team(1,4,i,0))

Iters = 1000 #Iterations
ab = 20 #After burnout
A = np.array([[1, -1]]) # A-vector in the calculations

#Main loop
nr_matches = len(input_data["ID1"])
correct_predictions = 0
used_matches = 0 #We only use matches that are not tied
for iteration in range(nr_matches):
    print(f"Calculating match {iteration+1} of {nr_matches}")
    i = iteration # Doing matches in sequence
    #i = nr_matches-1-iteration # doing matches in reverse
    #Get the score, if score is 0, the match is ignored
    score = input_data["PD"][i]
    if score == 0:
        continue
    used_matches += 1
    
    #Only the sign of the score is used
    score = int(score)
    true_score = score
    score = np.sign(score)

    #Get the correct team data by fetching the names and then using the classes corresponding to those names
    team_1_name = input_data["ID1"][i]
    team_2_name = input_data["ID2"][i]

    for j in range(len(team_data)):
        if team_data[j].name == team_1_name:
            team1 = team_data[j]
        if team_data[j].name == team_2_name:
            team2 = team_data[j]
    
    #Predicting outcome
    mu1 = team1.mu
    mu2 = team2.mu
    pred_outcome = prediction(mu1, mu2)
    if pred_outcome == score:
        correct_predictions += 1
        
        
    #Set up µ-vector and covariance matrix
    mu_s_vector = np.array([[team1.mu], [team2.mu]])
    std_s_matrix = np.array([[team1.var**2, 0], [0, team2.var**2]])

    All_S = np.zeros((Iters, 2)) #Containing drawn S values
    All_t = np.zeros(Iters) #Containing drawn t values

    # Matrices where the s1 and s2 random values are stored as well as the µ-values (in All_Mu_S)
    All_S[0] = [np.random.normal(loc=team1.mu, scale = team1.var), np.random.normal(loc=team2.mu, scale = team2.var)]

    # We calculate t, then s, and repeat for as many times as the iterations
    for j in range(Iters-1):
        All_t[j] = s_to_t(All_S[j,0], All_S[j,1], std_t, score)
        All_S[j+1] = t_to_s(All_t[j], A, std_t,std_s_matrix, mu_s_vector)

    #Getting s1 and s2 values
    y1 = [All_S[j][0] for j in range(ab,Iters)]
    y2 = [All_S[j][1] for j in range(ab,Iters)]

    #Getting µ and σ
    mu_team1 = np.mean(y1)
    mu_team2 = np.mean(y2)
    var_team1 = 0
    var_team2 = 0
    for j in range(len(y1)):
        var_team1 += (y1[j]-mu_team1)**2
        var_team2 += (y2[j]-mu_team2)**2
    var_team1 /= len(y1)-1
    var_team2 /= len(y1)-1
    var_team1 = math.sqrt(var_team1)
    var_team2 = math.sqrt(var_team2)
    team1.mu = mu_team1
    team2.mu = mu_team2
    team1.var = var_team1
    team2.var = var_team2

#Calculating prediction rate
prediction_rate = correct_predictions/used_matches 
    
#Drawing 100 random numbers from the distributions to determine skill
for current_team in team_data:
    for i in range(100):
        partial_skill = np.random.normal(loc=current_team.mu, scale = current_team.var)/100
        current_team.skill += partial_skill

team_data.sort(key=lambda team: team.skill, reverse=True)

print("TEAM SKILLS AND RANKINGS:")
for i in range(len(team_data)):
    print(f"{i+1}. {team_data[i].name}: Skill = {round(team_data[i].skill, 2)}, µ = {round(team_data[i].mu, 2)}, sig = {round(team_data[i].var, 2)}")
print(f"prediction rate = {prediction_rate}")
# Out:
# Calculating match 1 of 130
# Calculating match 2 of 130
# Calculating match 3 of 130
# Calculating match 4 of 130
# Calculating match 5 of 130
# Calculating match 6 of 130
# Calculating match 7 of 130
# Calculating match 8 of 130
# Calculating match 9 of 130
# Calculating match 10 of 130
# Calculating match 11 of 130
# Calculating match 12 of 130
# Calculating match 13 of 130
# Calculating match 14 of 130
# Calculating match 15 of 130
# Calculating match 16 of 130
# Calculating match 17 of 130
# Calculating match 18 of 130
# Calculating match 19 of 130
# Calculating match 20 of 130
# Calculating match 21 of 130
# Calculating match 22 of 130
# Calculating match 23 of 130
# Calculating match 24 of 130
# Calculating match 25 of 130
# Calculating match 26 of 130
# Calculating match 27 of 130
# Calculating match 28 of 130
# Calculating match 29 of 130
# Calculating match 30 of 130
# Calculating match 31 of 130
# Calculating match 32 of 130
# Calculating match 33 of 130
# Calculating match 34 of 130
# Calculating match 35 of 130
# Calculating match 36 of 130
# Calculating match 37 of 130
# Calculating match 38 of 130
# Calculating match 39 of 130
# Calculating match 40 of 130
# Calculating match 41 of 130
# Calculating match 42 of 130
# Calculating match 43 of 130
# Calculating match 44 of 130
# Calculating match 45 of 130
# Calculating match 46 of 130
# Calculating match 47 of 130
# Calculating match 48 of 130
# Calculating match 49 of 130
# Calculating match 50 of 130
# Calculating match 51 of 130
# Calculating match 52 of 130
# Calculating match 53 of 130
# Calculating match 54 of 130
# Calculating match 55 of 130
# Calculating match 56 of 130
# Calculating match 57 of 130
# Calculating match 58 of 130
# Calculating match 59 of 130
# Calculating match 60 of 130
# Calculating match 61 of 130
# Calculating match 62 of 130
# Calculating match 63 of 130
# Calculating match 64 of 130
# Calculating match 65 of 130
# Calculating match 66 of 130
# Calculating match 67 of 130
# Calculating match 68 of 130
# Calculating match 69 of 130
# Calculating match 70 of 130
# Calculating match 71 of 130
# Calculating match 72 of 130
# Calculating match 73 of 130
# Calculating match 74 of 130
# Calculating match 75 of 130
# Calculating match 76 of 130
# Calculating match 77 of 130
# Calculating match 78 of 130
# Calculating match 79 of 130
# Calculating match 80 of 130
# Calculating match 81 of 130
# Calculating match 82 of 130
# Calculating match 83 of 130
# Calculating match 84 of 130
# Calculating match 85 of 130
# Calculating match 86 of 130
# Calculating match 87 of 130
# Calculating match 88 of 130
# Calculating match 89 of 130
# Calculating match 90 of 130
# Calculating match 91 of 130
# Calculating match 92 of 130
# Calculating match 93 of 130
# Calculating match 94 of 130
# Calculating match 95 of 130
# Calculating match 96 of 130
# Calculating match 97 of 130
# Calculating match 98 of 130
# Calculating match 99 of 130
# Calculating match 100 of 130
# Calculating match 101 of 130
# Calculating match 102 of 130
# Calculating match 103 of 130
# Calculating match 104 of 130
# Calculating match 105 of 130
# Calculating match 106 of 130
# Calculating match 107 of 130
# Calculating match 108 of 130
# Calculating match 109 of 130
# Calculating match 110 of 130
# Calculating match 111 of 130
# Calculating match 112 of 130
# Calculating match 113 of 130
# Calculating match 114 of 130
# Calculating match 115 of 130
# Calculating match 116 of 130
# Calculating match 117 of 130
# Calculating match 118 of 130
# Calculating match 119 of 130
# Calculating match 120 of 130
# Calculating match 121 of 130
# Calculating match 122 of 130
# Calculating match 123 of 130
# Calculating match 124 of 130
# Calculating match 125 of 130
# Calculating match 126 of 130
# Calculating match 127 of 130
# Calculating match 128 of 130
# Calculating match 129 of 130
# Calculating match 130 of 130
# TEAM SKILLS AND RANKINGS:
# 1. 3: Skill = 38.69, µ = 39.06, sig = 9.71
# 2. 2: Skill = 28.58, µ = 28.01, sig = 6.31
# 3. 5: Skill = 18.86, µ = 18.73, sig = 6.7
# 4. 1: Skill = 17.15, µ = 17.63, sig = 7.46
# 5. 27: Skill = 13.56, µ = 13.38, sig = 5.27
# 6. 7: Skill = 11.1, µ = 10.26, sig = 8.71
# 7. 25: Skill = 8.24, µ = 7.72, sig = 5.42
# 8. 4: Skill = 8.16, µ = 8.8, sig = 8.32
# 9. 6: Skill = 8.15, µ = 7.81, sig = 4.46
# 10. 21: Skill = 7.19, µ = 6.71, sig = 5.14
# 11. 13: Skill = 4.51, µ = 6.29, sig = 8.45
# 12. 15: Skill = 3.69, µ = 3.77, sig = 5.44
# 13. 14: Skill = 1.51, µ = 1.47, sig = 4.56
# 14. 10: Skill = 1.11, µ = 2.02, sig = 6.07
# 15. 11: Skill = 1.08, µ = 0.58, sig = 6.28
# 16. 26: Skill = 0.23, µ = -0.89, sig = 5.66
# 17. 8: Skill = -0.32, µ = 0.66, sig = 4.57
# 18. 12: Skill = -2.66, µ = -1.91, sig = 4.93
# 19. 17: Skill = -2.77, µ = -2.58, sig = 7.59
# 20. 19: Skill = -2.97, µ = -3.24, sig = 4.39
# 21. 18: Skill = -3.39, µ = -2.83, sig = 5.34
# 22. 9: Skill = -3.45, µ = -3.93, sig = 10.47
# 23. 24: Skill = -4.14, µ = -3.96, sig = 5.2
# 24. 30: Skill = -6.53, µ = -6.16, sig = 5.17
# 25. 20: Skill = -6.63, µ = -6.36, sig = 6.21
# 26. 23: Skill = -6.98, µ = -6.95, sig = 5.38
# 27. 28: Skill = -7.37, µ = -8.41, sig = 5.96
# 28. 22: Skill = -8.43, µ = -7.92, sig = 5.71
# 29. 31: Skill = -10.55, µ = -10.49, sig = 5.08
# 30. 32: Skill = -10.91, µ = -10.24, sig = 8.84
# 31. 33: Skill = -13.7, µ = -12.76, sig = 7.03
# 32. 29: Skill = -14.48, µ = -12.64, sig = 7.41
# 33. 16: Skill = -15.33, µ = -14.52, sig = 5.92
# 34. 34: Skill = -17.53, µ = -17.65, sig = 6.31
# prediction rate = 0.6076923076923076

# %%
# Q11

#Class for every team, showing µ, σ and team name
class team:
    def __init__(self, mu, var, name, skill):
        self.mu = mu
        self.var = var
        self.name = name
        self.skill = skill

def s_to_t(s1, s2, std_t, true_score): #Function to get t|s1,s2,y with s1, s2 as given values
    score=np.sign(true_score)
    if score == -1:
        minval, maxval = -np.inf, 0
    else:
        minval, maxval = 0, np.inf
    # adding true_score/2 to shift the truncnorm
    return truncnorm.rvs(minval - (s1-s2)/std_t+true_score/2, (maxval - (s1-s2)/std_t)+true_score/2, loc = (s1-s2), scale = std_t)

def t_to_s(t, A, std_t,std_s_matrix, mu_s_vector): #Function to get s1,s2|t,y with t as a given value
    std_s_matrix_old = std_s_matrix
    std_s_matrix = np.linalg.inv(np.linalg.inv(std_s_matrix_old) + (A.reshape(-1, 1) * (1/std_t)) @ A)
    mu_s_vector = std_s_matrix@(np.linalg.inv(std_s_matrix_old) @ mu_s_vector + A.reshape(-1, 1) * (1/std_t)*t)
    mu_s_transpose = mu_s_vector.reshape(1, -1)[0]
    return np.random.multivariate_normal(mu_s_transpose, std_s_matrix)

std_t = 5 # starting σ for t

#Reads the data, the path has to be changed depending on where your target folder is in vs code, here the target folder is AML
input_data = pd.read_csv("res_fence_short.csv")

input_data

#Creates list of names
team_list = []
for teams in input_data["ID1"]:
    if teams not in team_list:
        team_list.append(teams)

for teams in input_data["ID2"]:
    if teams not in team_list:
        team_list.append(teams)

#Creates a list with all the teams (i.e. a list of classes)
team_data = []
for i in team_list:
    team_data.append(team(1,4,i,0))

Iters = 1000 #Iterations
ab = 20 #After burnout
A = np.array([[1, -1]]) # A-vector in the calculations

#Main loop
nr_matches = len(input_data["ID1"])
correct_predictions = 0
used_matches = 0 #We only use matches that are not tied
for iteration in range(nr_matches):
    print(f"Calculating match {iteration+1} of {nr_matches}")
    i = iteration # Doing matches in sequence
    #i = nr_matches-1-iteration # doing matches in reverse
    #Get the score, if score is 0, the match is ignored
    score = input_data["PD"][i]
    if score == 0:
        continue
    used_matches += 1

    #Only the sign of the score is used
    score = int(score)
    true_score = score
    score = np.sign(score)

    #Get the correct team data by fetching the names and then using the classes corresponding to those names
    team_1_name = input_data["ID1"][i]
    team_2_name = input_data["ID2"][i]

    for j in range(len(team_data)):
        if team_data[j].name == team_1_name:
            team1 = team_data[j]
        if team_data[j].name == team_2_name:
            team2 = team_data[j]
            
    #Predicting outcome
    mu1 = team1.mu
    mu2 = team2.mu
    pred_outcome = prediction(mu1, mu2)
    if pred_outcome == score:
        correct_predictions += 1
        
        
    skill_dif = team1.name - team2.name
    skill_sign = np.sign(skill_dif)
    

    #Set up µ-vector and covariance matrix
    mu_s_vector = np.array([[team1.mu], [team2.mu]])
    std_s_matrix = np.array([[team1.var**2, 0], [0, team2.var**2]])

    All_S = np.zeros((Iters, 2)) #Containing drawn S values
    All_t = np.zeros(Iters) #Containing drawn t values

    # Matrices where the s1 and s2 random values are stored as well as the µ-values (in All_Mu_S)
    All_S[0] = [np.random.normal(loc=team1.mu, scale = team1.var), np.random.normal(loc=team2.mu, scale = team2.var)]

    # We calculate t, then s, and repeat for as many times as the iterations
    for j in range(Iters-1):
        All_t[j] = s_to_t(All_S[j,0], All_S[j,1], std_t, true_score)
        All_S[j+1] = t_to_s(All_t[j], A, std_t,std_s_matrix, mu_s_vector)

    #Getting s1 and s2 values
    y1 = [All_S[j][0] for j in range(ab,Iters)]
    y2 = [All_S[j][1] for j in range(ab,Iters)]

    #Getting µ and σ
    mu_team1 = np.mean(y1)
    mu_team2 = np.mean(y2)
    var_team1 = 0
    var_team2 = 0
    for j in range(len(y1)):
        var_team1 += (y1[j]-mu_team1)**2
        var_team2 += (y2[j]-mu_team2)**2
    var_team1 /= len(y1)-1
    var_team2 /= len(y1)-1
    var_team1 = math.sqrt(var_team1)
    var_team2 = math.sqrt(var_team2)
    team1.mu = mu_team1
    team2.mu = mu_team2
    team1.var = var_team1
    team2.var = var_team2

#Calculating prediction rate
prediction_rate = correct_predictions/used_matches

#Drawing 100 random numbers from the distributions to determine skill
for current_team in team_data:
    for i in range(100):
        partial_skill = np.random.normal(loc=current_team.mu, scale = current_team.var)/100
        current_team.skill += partial_skill

team_data.sort(key=lambda team: team.skill, reverse=True)

print("TEAM SKILLS AND RANKINGS:")
for i in range(len(team_data)):
    print(f"{i+1}. {team_data[i].name}: {round(team_data[i].skill, 2)}")
print(f"prediction rate = {prediction_rate}")
# Out:
# Calculating match 1 of 130
# Calculating match 2 of 130
# Calculating match 3 of 130
# Calculating match 4 of 130
# Calculating match 5 of 130
# Calculating match 6 of 130
# Calculating match 7 of 130
# Calculating match 8 of 130
# Calculating match 9 of 130
# Calculating match 10 of 130
# Calculating match 11 of 130
# Calculating match 12 of 130
# Calculating match 13 of 130
# Calculating match 14 of 130
# Calculating match 15 of 130
# Calculating match 16 of 130
# Calculating match 17 of 130
# Calculating match 18 of 130
# Calculating match 19 of 130
# Calculating match 20 of 130
# Calculating match 21 of 130
# Calculating match 22 of 130
# Calculating match 23 of 130
# Calculating match 24 of 130
# Calculating match 25 of 130
# Calculating match 26 of 130
# Calculating match 27 of 130
# Calculating match 28 of 130
# Calculating match 29 of 130
# Calculating match 30 of 130
# Calculating match 31 of 130
# Calculating match 32 of 130
# Calculating match 33 of 130
# Calculating match 34 of 130
# Calculating match 35 of 130
# Calculating match 36 of 130
# Calculating match 37 of 130
# Calculating match 38 of 130
# Calculating match 39 of 130
# Calculating match 40 of 130
# Calculating match 41 of 130
# Calculating match 42 of 130
# Calculating match 43 of 130
# Calculating match 44 of 130
# Calculating match 45 of 130
# Calculating match 46 of 130
# Calculating match 47 of 130
# Calculating match 48 of 130
# Calculating match 49 of 130
# Calculating match 50 of 130
# Calculating match 51 of 130
# Calculating match 52 of 130
# Calculating match 53 of 130
# Calculating match 54 of 130
# Calculating match 55 of 130
# Calculating match 56 of 130
# Calculating match 57 of 130
# Calculating match 58 of 130
# Calculating match 59 of 130
# Calculating match 60 of 130
# Calculating match 61 of 130
# Calculating match 62 of 130
# Calculating match 63 of 130
# Calculating match 64 of 130
# Calculating match 65 of 130
# Calculating match 66 of 130
# Calculating match 67 of 130
# Calculating match 68 of 130
# Calculating match 69 of 130
# Calculating match 70 of 130
# Calculating match 71 of 130
# Calculating match 72 of 130
# Calculating match 73 of 130
# Calculating match 74 of 130
# Calculating match 75 of 130
# Calculating match 76 of 130
# Calculating match 77 of 130
# Calculating match 78 of 130
# Calculating match 79 of 130
# Calculating match 80 of 130
# Calculating match 81 of 130
# Calculating match 82 of 130
# Calculating match 83 of 130
# Calculating match 84 of 130
# Calculating match 85 of 130
# Calculating match 86 of 130
# Calculating match 87 of 130
# Calculating match 88 of 130
# Calculating match 89 of 130
# Calculating match 90 of 130
# Calculating match 91 of 130
# Calculating match 92 of 130
# Calculating match 93 of 130
# Calculating match 94 of 130
# Calculating match 95 of 130
# Calculating match 96 of 130
# Calculating match 97 of 130
# Calculating match 98 of 130
# Calculating match 99 of 130
# Calculating match 100 of 130
# Calculating match 101 of 130
# Calculating match 102 of 130
# Calculating match 103 of 130
# Calculating match 104 of 130
# Calculating match 105 of 130
# Calculating match 106 of 130
# Calculating match 107 of 130
# Calculating match 108 of 130
# Calculating match 109 of 130
# Calculating match 110 of 130
# Calculating match 111 of 130
# Calculating match 112 of 130
# Calculating match 113 of 130
# Calculating match 114 of 130
# Calculating match 115 of 130
# Calculating match 116 of 130
# Calculating match 117 of 130
# Calculating match 118 of 130
# Calculating match 119 of 130
# Calculating match 120 of 130
# Calculating match 121 of 130
# Calculating match 122 of 130
# Calculating match 123 of 130
# Calculating match 124 of 130
# Calculating match 125 of 130
# Calculating match 126 of 130
# Calculating match 127 of 130
# Calculating match 128 of 130
# Calculating match 129 of 130
# Calculating match 130 of 130
# TEAM SKILLS AND RANKINGS:
# 1. 3: 41.85
# 2. 2: 34.65
# 3. 1: 25.48
# 4. 7: 15.91
# 5. 5: 15.05
# 6. 6: 9.45
# 7. 13: 8.93
# 8. 21: 8.77
# 9. 27: 8.46
# 10. 4: 6.4
# 11. 10: 5.05
# 12. 25: 4.99
# 13. 15: 4.32
# 14. 14: 2.78
# 15. 26: 1.55
# 16. 11: 0.5
# 17. 12: -0.17
# 18. 8: -0.38
# 19. 18: -4.11
# 20. 20: -4.55
# 21. 19: -4.59
# 22. 9: -5.51
# 23. 17: -5.55
# 24. 24: -5.9
# 25. 30: -7.66
# 26. 22: -8.69
# 27. 28: -8.9
# 28. 23: -10.11
# 29. 31: -13.11
# 30. 32: -13.32
# 31. 29: -14.63
# 32. 33: -17.22
# 33. 16: -19.64
# 34. 34: -22.6
# prediction rate = 0.6153846153846154
